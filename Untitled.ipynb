# %%
import pandas as pd

# %%
rdt = pd.read_csv('realdonaldtrump.csv')

# %%
bo = pd.read_csv('Tweets-BarackObama.csv')

# %%
rdt.head()
# Out:
#            id                                               link  \
# 0  1698308935  https://twitter.com/realDonaldTrump/status/169...
# 1  1701461182  https://twitter.com/realDonaldTrump/status/170...
# 2  1737479987  https://twitter.com/realDonaldTrump/status/173...
# 3  1741160716  https://twitter.com/realDonaldTrump/status/174...
# 4  1773561338  https://twitter.com/realDonaldTrump/status/177...
#
#                                              content                 date  \
# 0  Be sure to tune in and watch Donald Trump on L...  2009-05-04 13:54:25
# 1  Donald Trump will be appearing on The View tom...  2009-05-04 20:00:10
# 2  Donald Trump reads Top Ten Financial Tips on L...  2009-05-08 08:38:08
# 3  New Blog Post: Celebrity Apprentice Finale and...  2009-05-08 15:40:15
# 4  "My persona will never be that of a wallflower...  2009-05-12 09:07:28
#
#    retweets  favorites mentions hashtags
# 0       510        917      NaN      NaN
# 1        34        267      NaN      NaN
# ...

# %%
bo.head()
# Out:
#                Date                         Username  \
# 0  2019/04/10_17:08  https://twitter.com/BarackObama
# 1  2019/04/06_06:16  https://twitter.com/BarackObama
# 2  2019/04/05_09:25  https://twitter.com/BarackObama
# 3  2019/04/04_12:23  https://twitter.com/BarackObama
# 4  2019/04/03_12:07  https://twitter.com/BarackObama
#
#                                           Tweet-text  \
# 0  From a big NBA fan congrats to future Hall of ...
# 1  In just a few minutes I’m taking the stage at ...
# 2  A voice everybody should hear.https://twitter....
# 3  Here’s a story about people doing good that's ...
# 4  Great to see Chicago’s historic mayoral race b...
#
#                                           Tweet Link  Retweets   Likes  \
# 0  https://twitter.com/BarackObama/status/1116130...     20954  175133
# 1  https://twitter.com/BarackObama/status/1114517...      5206   36179
# 2  https://twitter.com/BarackObama/status/1114202...     27938  134604
# ...

# %% [markdown]
# * Clean up to do:
# - Standardize date formats (separate out day, month, year)
# - Split up text into arrays
# - Check tweets vs. retweets (decide to categorize or

# %%
print('obama', bo['Date'].nunique(), 'trump', rdt['date'].nunique())
# Out:
# obama 6768 trump 42979

# %%
bo['Year'] = bo['Date'].apply(lambda x: x[:4])
rdt['Year'] = rdt['date'].apply(lambda x: x[:4])

# %%
bo.head()
# Out:
#                Date                         Username  \
# 0  2019/04/10_17:08  https://twitter.com/BarackObama
# 1  2019/04/06_06:16  https://twitter.com/BarackObama
# 2  2019/04/05_09:25  https://twitter.com/BarackObama
# 3  2019/04/04_12:23  https://twitter.com/BarackObama
# 4  2019/04/03_12:07  https://twitter.com/BarackObama
#
#                                           Tweet-text  \
# 0  From a big NBA fan congrats to future Hall of ...
# 1  In just a few minutes I’m taking the stage at ...
# 2  A voice everybody should hear.https://twitter....
# 3  Here’s a story about people doing good that's ...
# 4  Great to see Chicago’s historic mayoral race b...
#
#                                           Tweet Link  Retweets   Likes  \
# 0  https://twitter.com/BarackObama/status/1116130...     20954  175133
# 1  https://twitter.com/BarackObama/status/1114517...      5206   36179
# 2  https://twitter.com/BarackObama/status/1114202...     27938  134604
# ...

# %%
rdt.head()
# Out:
#            id                                               link  \
# 0  1698308935  https://twitter.com/realDonaldTrump/status/169...
# 1  1701461182  https://twitter.com/realDonaldTrump/status/170...
# 2  1737479987  https://twitter.com/realDonaldTrump/status/173...
# 3  1741160716  https://twitter.com/realDonaldTrump/status/174...
# 4  1773561338  https://twitter.com/realDonaldTrump/status/177...
#
#                                              content                 date  \
# 0  Be sure to tune in and watch Donald Trump on L...  2009-05-04 13:54:25
# 1  Donald Trump will be appearing on The View tom...  2009-05-04 20:00:10
# 2  Donald Trump reads Top Ten Financial Tips on L...  2009-05-08 08:38:08
# 3  New Blog Post: Celebrity Apprentice Finale and...  2009-05-08 15:40:15
# 4  "My persona will never be that of a wallflower...  2009-05-12 09:07:28
#
#    retweets  favorites mentions hashtags  Year
# 0       510        917      NaN      NaN  2009
# ...
